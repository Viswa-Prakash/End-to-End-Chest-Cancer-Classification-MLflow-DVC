# %%
import os
os.chdir("../")
# %pwd
# Out:
# 'c:\\Users\\viswa\\Documents\\MLOPs\\End-to-End-Chest-Cancer-Classification-MLflow-DVC'

# %%
pip install mlflow dagshub
# Out:
# Requirement already satisfied: mlflow in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (2.2.2)
# Requirement already satisfied: dagshub in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (0.5.10)
# Requirement already satisfied: click<9,>=7.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<3 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (2.2.1)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (0.18.0)
# Requirement already satisfied: entrypoints<1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (3.1.44)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (6.0.2)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (4.25.7)
# Requirement already satisfied: pytz<2023 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (2022.7.1)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (2.32.3)
# Requirement already satisfied: packaging<24 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (23.2)
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (6.11.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (0.5.3)
# Requirement already satisfied: alembic<2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (1.16.1)
# Requirement already satisfied: docker<7,>=4.0.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (6.1.3)
# Requirement already satisfied: Flask<3 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: numpy<2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (1.23.5)
# Requirement already satisfied: scipy<2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: pandas<3 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: querystring-parser<2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (2.0.41)
# Requirement already satisfied: scikit-learn<2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: pyarrow<12,>=4.0.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (11.0.0)
# Requirement already satisfied: shap<1,>=0.40 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (0.47.2)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (3.8)
# Requirement already satisfied: matplotlib<4 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (3.10.3)
# Requirement already satisfied: waitress<3 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (2.1.2)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from mlflow) (3.1.6)
# Requirement already satisfied: Mako in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from alembic<2->mlflow) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from alembic<2->mlflow) (4.13.2)
# Requirement already satisfied: tomli in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from alembic<2->mlflow) (2.2.1)
# Requirement already satisfied: colorama in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.6)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.10.1)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.9.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.17.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.4.0)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from docker<7,>=4.0.0->mlflow) (1.8.0)
# Requirement already satisfied: pywin32>=304 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from docker<7,>=4.0.0->mlflow) (310)
# Requirement already satisfied: Werkzeug>=2.3.7 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from Flask<3->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from Flask<3->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from Flask<3->mlflow) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from matplotlib<4->mlflow) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from matplotlib<4->mlflow) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from matplotlib<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2025.4.26)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from scikit-learn<2->mlflow) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from shap<1,>=0.40->mlflow) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from shap<1,>=0.40->mlflow) (0.0.8)
# Requirement already satisfied: numba>=0.54 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from shap<1,>=0.40->mlflow) (0.60.0)
# Requirement already satisfied: greenlet>=1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.2)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (1.4.4)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (0.28.1)
# Requirement already satisfied: rich>=13.1.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (14.0.0)
# Requirement already satisfied: dacite~=1.6.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (1.6.0)
# Requirement already satisfied: tenacity>=8.2.2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (9.1.2)
# Requirement already satisfied: gql[requests] in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (3.5.3)
# Requirement already satisfied: dataclasses-json in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (0.6.7)
# Requirement already satisfied: treelib>=1.6.4 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (1.7.1)
# Requirement already satisfied: pathvalidate>=3.0.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (3.2.3)
# Requirement already satisfied: boto3 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (1.38.23)
# Requirement already satisfied: semver in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (3.0.4)
# Requirement already satisfied: dagshub-annotation-converter>=0.1.5 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub) (0.1.9)
# Requirement already satisfied: lxml in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub-annotation-converter>=0.1.5->dagshub) (5.4.0)
# Requirement already satisfied: pydantic>=2.0.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dagshub-annotation-converter>=0.1.5->dagshub) (2.11.5)
# Requirement already satisfied: anyio in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from httpx>=0.23.0->dagshub) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from httpx>=0.23.0->dagshub) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->dagshub) (0.16.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from numba>=0.54->shap<1,>=0.40->mlflow) (0.43.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from pydantic>=2.0.0->dagshub-annotation-converter>=0.1.5->dagshub) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from pydantic>=2.0.0->dagshub-annotation-converter>=0.1.5->dagshub) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from pydantic>=2.0.0->dagshub-annotation-converter>=0.1.5->dagshub) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from rich>=13.1.0->dagshub) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from rich>=13.1.0->dagshub) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.1.0->dagshub) (0.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from anyio->httpx>=0.23.0->dagshub) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from anyio->httpx>=0.23.0->dagshub) (1.3.1)
# Requirement already satisfied: botocore<1.39.0,>=1.38.23 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from boto3->dagshub) (1.38.23)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from boto3->dagshub) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from boto3->dagshub) (0.13.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dataclasses-json->dagshub) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from dataclasses-json->dagshub) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub) (1.1.0)
# Requirement already satisfied: graphql-core<3.2.7,>=3.2 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from gql[requests]->dagshub) (3.2.6)
# Requirement already satisfied: yarl<2.0,>=1.6 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from gql[requests]->dagshub) (1.20.0)
# Requirement already satisfied: backoff<3.0,>=1.11.1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from gql[requests]->dagshub) (2.2.1)
# Requirement already satisfied: requests-toolbelt<2,>=1.0.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from gql[requests]->dagshub) (1.0.0)
# Requirement already satisfied: multidict>=4.0 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from yarl<2.0,>=1.6->gql[requests]->dagshub) (6.4.4)
# Requirement already satisfied: propcache>=0.2.1 in c:\users\viswa\anaconda3\envs\chest\lib\site-packages (from yarl<2.0,>=1.6->gql[requests]->dagshub) (0.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dagshub
dagshub.init(
    repo_owner='Viswa-Prakash',
    repo_name='End-to-End-Chest-Cancer-Classification-MLflow-DVC',
    mlflow=True
)
# Out:
# Accessing as Viswa-Prakash
# Initialized MLflow to track repo "Viswa-Prakash/End-to-End-Chest-Cancer-Classification-MLflow-DVC"
# Repository Viswa-Prakash/End-to-End-Chest-Cancer-Classification-MLflow-DVC initialized!

# %%
import mlflow

# Set the MLflow tracking URI to DagsHub's MLflow server
mlflow_tracking_uri = 'https://dagshub.com/Viswa-Prakash/End-to-End-Chest-Cancer-Classification-MLflow-DVC.mlflow'
mlflow.set_tracking_uri(mlflow_tracking_uri)

# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model("artifacts/training/model.h5")

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class EvaluationConfig:
    path_of_model: Path
    training_data: Path
    all_params: dict
    mlflow_uri: str
    params_image_size: list
    params_batch_size: int

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories, save_json

# %%
class ConfigurationManager:
    def __init__(
        self, 
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])

    
    def get_evaluation_config(self) -> EvaluationConfig:
        eval_config = EvaluationConfig(
            path_of_model="artifacts/training/model.h5",
            training_data="artifacts/data_ingestion/Chest-CT-Scan-data",
            mlflow_uri="https://dagshub.com/Viswa-Prakash/End-to-End-Chest-Cancer-Classification-MLflow-DVC.mlflow",
            all_params=self.params,
            params_image_size=self.params.IMAGE_SIZE,
            params_batch_size=self.params.BATCH_SIZE
        )
        return eval_config

# %%
import tensorflow as tf
from pathlib import Path
import mlflow
import mlflow.keras
from urllib.parse import urlparse

# %%
class Evaluation:
    def __init__(self, config: EvaluationConfig):
        self.config = config

    
    def _valid_generator(self):

        datagenerator_kwargs = dict(
            rescale = 1./255,
            validation_split=0.30
        )

        dataflow_kwargs = dict(
            target_size=self.config.params_image_size[:-1],
            batch_size=self.config.params_batch_size,
            interpolation="bilinear"
        )

        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )

        self.valid_generator = valid_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="validation",
            shuffle=False,
            **dataflow_kwargs
        )


    @staticmethod
    def load_model(path: Path) -> tf.keras.Model:
        return tf.keras.models.load_model(path)
    

    def evaluation(self):
        self.model = self.load_model(self.config.path_of_model)
        self._valid_generator()
        self.score = model.evaluate(self.valid_generator)
        self.save_score()

    def save_score(self):
        scores = {"loss": self.score[0], "accuracy": self.score[1]}
        save_json(path=Path("scores.json"), data=scores)

    
    def log_into_mlflow(self):
        mlflow.set_registry_uri(self.config.mlflow_uri)
        tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme
        
        with mlflow.start_run():
            mlflow.log_params(self.config.all_params)
            mlflow.log_metrics(
                {"loss": self.score[0], "accuracy": self.score[1]}
            )
            # Model registry does not work with file store
            if tracking_url_type_store != "file":

                # Register the model
                # There are other ways to use the Model Registry, which depends on the use case,
                # please refer to the doc for more information:
                # https://mlflow.org/docs/latest/model-registry.html#api-workflow
                mlflow.keras.log_model(self.model, "model", registered_model_name="VGG16Model")
            else:
                mlflow.keras.log_model(self.model, "model")

# %%
try:
    config = ConfigurationManager()
    eval_config = config.get_evaluation_config()
    evaluation = Evaluation(eval_config)
    evaluation.evaluation()
    evaluation.log_into_mlflow()

except Exception as e:
   raise e
# Out:
# [2025-05-26 10:17:38,341: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-05-26 10:17:38,356: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-05-26 10:17:38,361: INFO: common: created directory at: artifacts]
# Found 102 images belonging to 2 classes.
# 7/7 [==============================] - 37s 6s/step - loss: 13.2898 - accuracy: 0.5686
# [2025-05-26 10:18:15,643: INFO: common: json file saved at: scores.json]
# 2025/05/26 10:18:17 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# [2025-05-26 10:18:19,341: WARNING: save: Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 14). These functions will not be directly callable after loading.]
# INFO:tensorflow:Assets written to: C:\Users\viswa\AppData\Local\Temp\tmp4kytj8yy\model\data\model\assets
# [2025-05-26 10:18:20,222: INFO: builder_impl: Assets written to: C:\Users\viswa\AppData\Local\Temp\tmp4kytj8yy\model\data\model\assets]
# c:\Users\viswa\anaconda3\envs\chest\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# Successfully registered model 'VGG16Model'.
# 2025/05/26 10:19:01 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: VGG16Model, version 1
# Created version '1' of model 'VGG16Model'.
